# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayush2005292/ML/blob/main/lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
l = [ x**2 for x in range (1,11)]
print(l)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
stringlist = ['cat', 'dog', 'man']
s = [ x.upper() for x in stringlist]
print(stringlist)
# Out:
# ['cat', 'dog', 'man']

# %%
l = [ [1,2,3], [4,5], [6,7,8,9]]
l2 = [item for row in l for item in row ]
print(l2)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
stringlist = [ 'dog', 'elephant', 'cat']
filtered_strings = [x.upper() for x in stringlist if len(x) > 3]
print(filtered_strings)
# Out:
# ['ELEPHANT']
